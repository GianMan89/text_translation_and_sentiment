# %% [markdown]
# # Text Translation and Sentiment Analysis using Transformers

# %% [markdown]
# ## Project Overview:
#
# The objective of this project is to analyze the sentiment of movie reviews in three different languages - English, French, and Spanish. We have been given 30 movies, 10 in each language, along with their reviews and synopses in separate CSV files named `movie_reviews_eng.csv`, `movie_reviews_fr.csv`, and `movie_reviews_sp.csv`.
#
# - The first step of this project is to convert the French and Spanish reviews and synopses into English. This will allow us to analyze the sentiment of all reviews in the same language. We will be using pre-trained transformers from HuggingFace to achieve this task.
#
# - Once the translations are complete, we will create a single dataframe that contains all the movies along with their reviews, synopses, and year of release in all three languages. This dataframe will be used to perform sentiment analysis on the reviews of each movie.
#
# - Finally, we will use pretrained transformers from HuggingFace to analyze the sentiment of each review. The sentiment analysis results will be added to the dataframe. The final dataframe will have 30 rows
#
#
# The output of the project will be a CSV file with a header row that includes column names such as **Title**, **Year**, **Synopsis**, **Review**, **Review Sentiment**, and **Original Language**. The **Original Language** column will indicate the language of the review and synopsis (*en/fr/sp*) before translation. The dataframe will consist of 30 rows, with each row corresponding to a movie.

# %%
# imports
import pandas as pd
from transformers import MarianMTModel, MarianTokenizer
from transformers import pipeline

# %% [markdown]
# ### Get data from `.csv` files and then preprocess data

# %%
pd.read_csv("data/movie_reviews_eng.csv").head()
# Out:
#            Movie / TV Series  Year  \
# 0  The Shawshank Redemption   1994
# 1           The Dark Knight   2008
# 2               Forrest Gump  1994
# 3             The Godfather   1972
# 4                  Inception  2010
#
#                                             Synopsis  \
# 0  Andy Dufresne (Tim Robbins), a successful bank...
# 1  Batman (Christian Bale) teams up with District...
# 2  Forrest Gump (Tom Hanks) is a simple man with ...
# 3  Don Vito Corleone (Marlon Brando) is the head ...
# 4  Dom Cobb (Leonardo DiCaprio) is a skilled thie...
#
#                                               Review
# 0  "The Shawshank Redemption is an inspiring tale...
# 1  "The Dark Knight is a thrilling and intense su...
# 2  "Forrest Gump is a heartwarming and inspiratio...
# 3  "The Godfather is a classic movie that stands ...
# 4  "Inception is a mind-bending and visually stun...

# %%
pd.read_csv("data/movie_reviews_fr.csv").head()
# Out:
#                                  Titre  Année  \
# 0                           La La Land   2016
# 1                         Intouchables   2011
# 2                               Amélie   2001
# 3                        Les Choristes   2004
# 4  Le Fabuleux Destin d'Amélie Poulain   2001
#
#                                             Synopsis  \
# 0  Cette comédie musicale raconte l'histoire d'un...
# 1  Ce film raconte l'histoire de l'amitié improba...
# 2  Cette comédie romantique raconte l'histoire d'...
# 3  Ce film raconte l'histoire d'un professeur de ...
# 4  Cette comédie romantique raconte l'histoire d'...
#
#                                            Critiques
# 0  "La La Land est un film absolument magnifique ...
# 1  "Intouchables est un film incroyablement touch...
# 2  "Amélie est un film absolument charmant qui vo...
# 3  "Les Choristes est un film magnifique qui vous...
# 4  "Le Fabuleux Destin d'Amélie Poulain est un fi...

# %%
pd.read_csv("data/movie_reviews_sp.csv").head()
# Out:
#                    Título          Año  \
# 0                    Roma         2018
# 1        La Casa de Papel  (2017-2021)
# 2       Y tu mamá también         2001
# 3  El Laberinto del Fauno         2006
# 4           Amores perros         2000
#
#                                             Sinopsis  \
# 0  Cleo (Yalitza Aparicio) es una joven empleada ...
# 1  Esta serie de televisión española sigue a un g...
# 2  Dos amigos adolescentes (Gael García Bernal y ...
# 3  Durante la posguerra española, Ofelia (Ivana B...
# 4  Tres historias se entrelazan en esta película ...
#
#                                             Críticas
# 0  "Roma es una película hermosa y conmovedora qu...
# 1  "La Casa de Papel es una serie emocionante y a...
# 2  "Y tu mamá también es una película que se qued...
# 3  "El Laberinto del Fauno es una película fascin...
# 4  "Amores perros es una película intensa y conmo...

# %%
# use the `pd.read_csv()` function to read the movie_review_*.csv files into 3 separate pandas dataframes

# Note: All the dataframes would have different column names. For testing purposes
# you should have the following column names/headers -> [Title, Year, Synopsis, Review]


def preprocess_data() -> pd.DataFrame:
    """
    Reads movie data from .csv files, map column names, add the "Original Language" column,
    and finally concatenate in one resultant dataframe called "df".
    """
    # load all three dataframes
    df_eng = pd.read_csv("data/movie_reviews_eng.csv")
    df_fr = pd.read_csv("data/movie_reviews_fr.csv")
    df_sp = pd.read_csv("data/movie_reviews_sp.csv")
    # map column names
    column_names = ["Title", "Year", "Synopsis", "Review"]
    df_eng.columns = column_names
    df_fr.columns = column_names
    df_sp.columns = column_names
    # add "Original Language" column
    df_eng["Original Language"] = "English"
    df_fr["Original Language"] = "French"
    df_sp["Original Language"] = "Spanish"
    # concatenate dataframes
    df = pd.concat([df_eng, df_fr, df_sp], ignore_index=True)

    return df


df = preprocess_data()

# %%
df.sample(10)
# Out:
#                                   Title  Year  \
# 9                            The Island  2005
# 4                             Inception  2010
# 6           Scott Pilgrim vs. the World  2010
# 13                        Les Choristes  2004
# 14  Le Fabuleux Destin d'Amélie Poulain  2001
# 18            Les Visiteurs en Amérique  2000
# 5                     Blade Runner 2049  2017
# 12                               Amélie  2001
# 22                    Y tu mamá también  2001
# 15                     Le Dîner de Cons  1998
#
#                                              Synopsis  \
# 9   In a future where people are cloned for organ ...
# 4   Dom Cobb (Leonardo DiCaprio) is a skilled thie...
# 6   Scott Pilgrim (Michael Cera) must defeat his n...
# 13  Ce film raconte l'histoire d'un professeur de ...
# 14  Cette comédie romantique raconte l'histoire d'...
# 18  Dans cette suite de la comédie française Les V...
# 5   Officer K (Ryan Gosling), a new blade runner f...
# ...

# %% [markdown]
# ### Text translation
#
# Translate the **Review** and **Synopsis** column values to English.

# %%
# load translation models and tokenizers
# use pre-trained huggingface models
# https://huggingface.co/Helsinki-NLP/opus-mt-fr-en
# https://huggingface.co/docs/transformers/model_doc/marian

fr_en_model_name = "Helsinki-NLP/opus-mt-fr-en"
es_en_model_name = "Helsinki-NLP/opus-mt-es-en"

# load the models
fr_en_model = MarianMTModel.from_pretrained(fr_en_model_name)
es_en_model = MarianMTModel.from_pretrained(es_en_model_name)

# load the tokenizers
fr_en_tokenizer = MarianTokenizer.from_pretrained(fr_en_model_name)
es_en_tokenizer = MarianTokenizer.from_pretrained(es_en_model_name)


def translate(text: str, model, tokenizer) -> str:
    """
    function to translate a text using a model and tokenizer
    """
    # encode the text using the tokenizer
    inputs = tokenizer(text, return_tensors="pt", padding=True)

    # generate the translation using the model
    outputs = model.generate(**inputs)

    # decode the generated output and return the translated text
    decoded = [tokenizer.decode(o, skip_special_tokens=True) for o in outputs]
    return decoded
# Out:
# d:\8_Udacity\5_git\text_translation_and_sentiment\.venv\Lib\site-packages\transformers\models\marian\tokenization_marian.py:194: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
# filter reviews in French and translate to English
fr_reviews = df[df["Original Language"] == "French"]["Review"]
fr_reviews_en = [
    translate(fr_reviews_str, fr_en_model, fr_en_tokenizer)
    for fr_reviews_str in fr_reviews
]

# filter synopsis in French and translate to English
fr_synopsis = df[df["Original Language"] == "French"]["Synopsis"]
fr_synopsis_en = [
    translate(fr_synopsis_str, fr_en_model, fr_en_tokenizer)
    for fr_synopsis_str in fr_synopsis
]

# filter reviews in Spanish and translate to English
es_reviews = df[df["Original Language"] == "Spanish"]["Review"]
es_reviews_en = [
    translate(es_reviews_str, es_en_model, es_en_tokenizer)
    for es_reviews_str in es_reviews
]

# filter synopsis in Spanish and translate to English
es_synopsis = df[df["Original Language"] == "Spanish"]["Synopsis"]
es_synopsis_en = [
    translate(es_synopsis_str, es_en_model, es_en_tokenizer)
    for es_synopsis_str in es_synopsis
]

# update dataframe with translated text
# add the translated reviews and synopsis - you can overwrite the existing data
df.loc[df["Original Language"] == "French", "Review"] = fr_reviews_en
df.loc[df["Original Language"] == "French", "Synopsis"] = fr_synopsis_en
df.loc[df["Original Language"] == "Spanish", "Review"] = es_reviews_en
df.loc[df["Original Language"] == "Spanish", "Synopsis"] = es_synopsis_en
# Out:
# d:\8_Udacity\5_git\text_translation_and_sentiment\.venv\Lib\site-packages\transformers\generation\utils.py:1369: UserWarning: Using `max_length`'s default (512) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(

# %%
df.sample(10)
# Out:
#                                   Title         Year  \
# 12                               Amélie         2001
# 26                              Toc Toc         2017
# 10                           La La Land         2016
# 29                         El Incidente         2014
# 11                         Intouchables         2011
# 15                     Le Dîner de Cons         1998
# 22                    Y tu mamá también         2001
# 14  Le Fabuleux Destin d'Amélie Poulain         2001
# 18            Les Visiteurs en Amérique         2000
# 21                     La Casa de Papel  (2017-2021)
#
#                                              Synopsis  \
# 12  This romantic comedy tells the story of Amélie...
# 26  In this Spanish comedy, a group of people with...
# 10  This musical tells the story of a budding actr...
# 29  In this Mexican horror film, a group of people...
# 11  This film tells the story of the unlikely frie...
# ...

# %% [markdown]
# ### Sentiment Analysis
#
# Use HuggingFace pretrained model for sentiment analysis of the reviews. Store the sentiment result **Positive** or **Negative** in a new column titled **Sentiment** in the dataframe.

# %%
# load sentiment analysis model
# use the following huggingface model that classifies text as either positive or negaitve:
model_name = "finiteautomata/bertweet-base-sentiment-analysis"
sentiment_classifier = pipeline(model=model_name)


def analyze_sentiment(text, classifier):
    """
    function to perform sentiment analysis on a text using a model
    """
    result = classifier(text)
    return result[0]["label"]
# Out:
# emoji is not installed, thus not converting emoticons or emojis into text. Install emoji: pip3 install emoji==0.6.0
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
# perform sentiment analysis on reviews and store results in new column
en_reviews = df["Review"]
en_sentiment = [
    "Positive"
    if analyze_sentiment(en_review_str, sentiment_classifier) == "POS"
    else "Negative"
    for en_review_str in en_reviews
]

# store results in new column
df["Sentiment"] = en_sentiment

# %%
df.sample(10)
# Out:
#                         Title         Year  \
# 0   The Shawshank Redemption          1994
# 18  Les Visiteurs en Amérique         2000
# 4                   Inception         2010
# 11               Intouchables         2011
# 26                    Toc Toc         2017
# 15           Le Dîner de Cons         1998
# 3              The Godfather          1972
# 27                     El Bar         2017
# 25               Águila Roja   (2009-2016)
# 20                       Roma         2018
#
#                                              Synopsis  \
# 0   Andy Dufresne (Tim Robbins), a successful bank...
# 18  In this continuation of the French comedy The ...
# 4   Dom Cobb (Leonardo DiCaprio) is a skilled thie...
# 11  This film tells the story of the unlikely frie...
# 26  In this Spanish comedy, a group of people with...
# 15  The film follows the story of a group of rich ...
# 3   Don Vito Corleone (Marlon Brando) is the head ...
# ...

# %%
# export the results to a .csv file
df.to_csv("result/reviews_with_sentiment.csv", index=False)
